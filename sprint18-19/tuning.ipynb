# %% [markdown]
# ## ハイパーパラメータチューニング
#
# sprint18-19のハイパーパラメータチューニング部分のノートブックです。
#
# ## optimizerのチューニング

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = '../input/stage1_train/'
TEST_PATH = '../input/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [01:24<00:00,  7.96it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:00<00:00, 92.03it/s]
# Done!

# %%
# IoU metric を定義
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %% [markdown]
# compile(self, optimizer, loss, metrics=None, sample_weight_mode=None, weighted_metrics=None, target_tensors=None)

# %%
# U-Net model　構築
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (s)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])

from keras import optimizers
params={}

params['sgd'] = optimizers.SGD(lr=0.01, clipvalue=0.5)
params['Adam'] =optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
params['RMSprop'] = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
params['Adagrad'] = optimizers.Adagrad(lr=0.01, epsilon=None, decay=0.0)
params['Adadelta'] = optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0)
params['Nadam'] = optimizers.Nadam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004)
for key in params:
    model.compile(optimizer=key, loss='binary_crossentropy', metrics=[mean_iou])
    #model.summary()
    # Fit model
    earlystopper = EarlyStopping(patience=3, verbose=0)
    checkpointer = ModelCheckpoint('model-dsbowl2018-1'+key+'.h5', verbose=1, save_best_only=True)
    results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=8, epochs=30, verbose=1,
                        callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 45s 74ms/step - loss: 0.6255 - mean_iou: 0.4159 - val_loss: 0.5559 - val_mean_iou: 0.4237
#
# Epoch 00001: val_loss improved from inf to 0.55586, saving model to model-dsbowl2018-1sgd.h5
# Epoch 2/30
# 603/603 [==============================] - 40s 67ms/step - loss: 0.5121 - mean_iou: 0.4227 - val_loss: 0.4595 - val_mean_iou: 0.4236
#
# Epoch 00002: val_loss improved from 0.55586 to 0.45949, saving model to model-dsbowl2018-1sgd.h5
# Epoch 3/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.4542 - mean_iou: 0.4233 - val_loss: 0.4266 - val_mean_iou: 0.4236
#
# Epoch 00003: val_loss improved from 0.45949 to 0.42655, saving model to model-dsbowl2018-1sgd.h5
# Epoch 4/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.4394 - mean_iou: 0.4236 - val_loss: 0.4146 - val_mean_iou: 0.4236
#
# Epoch 00004: val_loss improved from 0.42655 to 0.41459, saving model to model-dsbowl2018-1sgd.h5
# Epoch 5/30
# 603/603 [==============================] - 39s 64ms/step - loss: 0.4328 - mean_iou: 0.4234 - val_loss: 0.4068 - val_mean_iou: 0.4236
#
# Epoch 00005: val_loss improved from 0.41459 to 0.40683, saving model to model-dsbowl2018-1sgd.h5
# Epoch 6/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.4289 - mean_iou: 0.4235 - val_loss: 0.4020 - val_mean_iou: 0.4236
#
# Epoch 00006: val_loss improved from 0.40683 to 0.40197, saving model to model-dsbowl2018-1sgd.h5
# Epoch 7/30
# 603/603 [==============================] - 40s 67ms/step - loss: 0.4258 - mean_iou: 0.4234 - val_loss: 0.3974 - val_mean_iou: 0.4236
#
# Epoch 00007: val_loss improved from 0.40197 to 0.39745, saving model to model-dsbowl2018-1sgd.h5
# Epoch 8/30
# 603/603 [==============================] - 41s 68ms/step - loss: 0.4232 - mean_iou: 0.4235 - val_loss: 0.3939 - val_mean_iou: 0.4236
#
# Epoch 00008: val_loss improved from 0.39745 to 0.39387, saving model to model-dsbowl2018-1sgd.h5
# Epoch 9/30
# 603/603 [==============================] - 40s 67ms/step - loss: 0.4203 - mean_iou: 0.4236 - val_loss: 0.3901 - val_mean_iou: 0.4236
#
# Epoch 00009: val_loss improved from 0.39387 to 0.39006, saving model to model-dsbowl2018-1sgd.h5
# Epoch 10/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.4173 - mean_iou: 0.4236 - val_loss: 0.3858 - val_mean_iou: 0.4236
#
# Epoch 00010: val_loss improved from 0.39006 to 0.38582, saving model to model-dsbowl2018-1sgd.h5
# Epoch 11/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.4138 - mean_iou: 0.4235 - val_loss: 0.3814 - val_mean_iou: 0.4236
#
# Epoch 00011: val_loss improved from 0.38582 to 0.38136, saving model to model-dsbowl2018-1sgd.h5
# Epoch 12/30
# 603/603 [==============================] - 39s 64ms/step - loss: 0.4098 - mean_iou: 0.4236 - val_loss: 0.3770 - val_mean_iou: 0.4236
#
# Epoch 00012: val_loss improved from 0.38136 to 0.37701, saving model to model-dsbowl2018-1sgd.h5
# Epoch 13/30
# 603/603 [==============================] - 38s 64ms/step - loss: 0.4053 - mean_iou: 0.4235 - val_loss: 0.3717 - val_mean_iou: 0.4236
#
# Epoch 00013: val_loss improved from 0.37701 to 0.37168, saving model to model-dsbowl2018-1sgd.h5
# Epoch 14/30
# 603/603 [==============================] - 35s 59ms/step - loss: 0.3995 - mean_iou: 0.4235 - val_loss: 0.3650 - val_mean_iou: 0.4236
#
# Epoch 00014: val_loss improved from 0.37168 to 0.36500, saving model to model-dsbowl2018-1sgd.h5
# Epoch 15/30
# 603/603 [==============================] - 36s 60ms/step - loss: 0.3918 - mean_iou: 0.4235 - val_loss: 0.3553 - val_mean_iou: 0.4236
#
# Epoch 00015: val_loss improved from 0.36500 to 0.35528, saving model to model-dsbowl2018-1sgd.h5
# Epoch 16/30
# 603/603 [==============================] - 37s 61ms/step - loss: 0.3817 - mean_iou: 0.4235 - val_loss: 0.3446 - val_mean_iou: 0.4236
#
# Epoch 00016: val_loss improved from 0.35528 to 0.34458, saving model to model-dsbowl2018-1sgd.h5
# Epoch 17/30
# 603/603 [==============================] - 37s 62ms/step - loss: 0.3688 - mean_iou: 0.4236 - val_loss: 0.3375 - val_mean_iou: 0.4236
#
# Epoch 00017: val_loss improved from 0.34458 to 0.33749, saving model to model-dsbowl2018-1sgd.h5
# Epoch 18/30
# 603/603 [==============================] - 40s 67ms/step - loss: 0.3519 - mean_iou: 0.4235 - val_loss: 0.3143 - val_mean_iou: 0.4236
#
# Epoch 00018: val_loss improved from 0.33749 to 0.31434, saving model to model-dsbowl2018-1sgd.h5
# Epoch 19/30
# 603/603 [==============================] - 36s 60ms/step - loss: 0.3287 - mean_iou: 0.4235 - val_loss: 0.2949 - val_mean_iou: 0.4236
#
# Epoch 00019: val_loss improved from 0.31434 to 0.29493, saving model to model-dsbowl2018-1sgd.h5
# Epoch 20/30
# 603/603 [==============================] - 37s 62ms/step - loss: 0.3010 - mean_iou: 0.4236 - val_loss: 0.2736 - val_mean_iou: 0.4236
#
# Epoch 00020: val_loss improved from 0.29493 to 0.27356, saving model to model-dsbowl2018-1sgd.h5
# Epoch 21/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.2765 - mean_iou: 0.4236 - val_loss: 0.2599 - val_mean_iou: 0.4236
#
# Epoch 00021: val_loss improved from 0.27356 to 0.25989, saving model to model-dsbowl2018-1sgd.h5
# Epoch 22/30
# 603/603 [==============================] - 38s 62ms/step - loss: 0.2612 - mean_iou: 0.4236 - val_loss: 0.2520 - val_mean_iou: 0.4236
#
# Epoch 00022: val_loss improved from 0.25989 to 0.25201, saving model to model-dsbowl2018-1sgd.h5
# Epoch 23/30
# 603/603 [==============================] - 36s 60ms/step - loss: 0.2479 - mean_iou: 0.4236 - val_loss: 0.2384 - val_mean_iou: 0.4237
#
# Epoch 00023: val_loss improved from 0.25201 to 0.23843, saving model to model-dsbowl2018-1sgd.h5
# Epoch 24/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.2384 - mean_iou: 0.4241 - val_loss: 0.2369 - val_mean_iou: 0.4246
#
# Epoch 00024: val_loss improved from 0.23843 to 0.23692, saving model to model-dsbowl2018-1sgd.h5
# Epoch 25/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.2311 - mean_iou: 0.4255 - val_loss: 0.2408 - val_mean_iou: 0.4265
#
# Epoch 00025: val_loss did not improve from 0.23692
# Epoch 26/30
# 603/603 [==============================] - 39s 64ms/step - loss: 0.2256 - mean_iou: 0.4279 - val_loss: 0.2121 - val_mean_iou: 0.4293
#
# Epoch 00026: val_loss improved from 0.23692 to 0.21207, saving model to model-dsbowl2018-1sgd.h5
# Epoch 27/30
# 603/603 [==============================] - 41s 67ms/step - loss: 0.2192 - mean_iou: 0.4311 - val_loss: 0.2366 - val_mean_iou: 0.4329
#
# Epoch 00027: val_loss did not improve from 0.21207
# Epoch 28/30
# 603/603 [==============================] - 41s 68ms/step - loss: 0.2163 - mean_iou: 0.4350 - val_loss: 0.2237 - val_mean_iou: 0.4371
#
# Epoch 00028: val_loss did not improve from 0.21207
# Epoch 29/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.2121 - mean_iou: 0.4392 - val_loss: 0.2091 - val_mean_iou: 0.4415
#
# Epoch 00029: val_loss improved from 0.21207 to 0.20908, saving model to model-dsbowl2018-1sgd.h5
# Epoch 30/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.2114 - mean_iou: 0.4438 - val_loss: 0.2196 - val_mean_iou: 0.4461
#
# Epoch 00030: val_loss did not improve from 0.20908
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 46s 76ms/step - loss: 0.2064 - mean_iou: 0.5599 - val_loss: 0.1940 - val_mean_iou: 0.5871
#
# Epoch 00001: val_loss improved from inf to 0.19402, saving model to model-dsbowl2018-1Adam.h5
# Epoch 2/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.1719 - mean_iou: 0.6057 - val_loss: 0.1376 - val_mean_iou: 0.6304
#
# Epoch 00002: val_loss improved from 0.19402 to 0.13756, saving model to model-dsbowl2018-1Adam.h5
# Epoch 3/30
# 603/603 [==============================] - 42s 69ms/step - loss: 0.1294 - mean_iou: 0.6544 - val_loss: 0.1330 - val_mean_iou: 0.6723
#
# Epoch 00003: val_loss improved from 0.13756 to 0.13296, saving model to model-dsbowl2018-1Adam.h5
# Epoch 4/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.1240 - mean_iou: 0.6870 - val_loss: 0.1092 - val_mean_iou: 0.6984
#
# Epoch 00004: val_loss improved from 0.13296 to 0.10921, saving model to model-dsbowl2018-1Adam.h5
# Epoch 5/30
# 603/603 [==============================] - 38s 64ms/step - loss: 0.1105 - mean_iou: 0.7088 - val_loss: 0.0955 - val_mean_iou: 0.7180
#
# Epoch 00005: val_loss improved from 0.10921 to 0.09549, saving model to model-dsbowl2018-1Adam.h5
# Epoch 6/30
# 603/603 [==============================] - 37s 61ms/step - loss: 0.1049 - mean_iou: 0.7261 - val_loss: 0.0971 - val_mean_iou: 0.7330
#
# Epoch 00006: val_loss did not improve from 0.09549
# Epoch 7/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.1052 - mean_iou: 0.7378 - val_loss: 0.0953 - val_mean_iou: 0.7429
#
# Epoch 00007: val_loss improved from 0.09549 to 0.09528, saving model to model-dsbowl2018-1Adam.h5
# Epoch 8/30
# 603/603 [==============================] - 37s 61ms/step - loss: 0.0989 - mean_iou: 0.7472 - val_loss: 0.0889 - val_mean_iou: 0.7522
#
# Epoch 00008: val_loss improved from 0.09528 to 0.08892, saving model to model-dsbowl2018-1Adam.h5
# Epoch 9/30
# 603/603 [==============================] - 35s 59ms/step - loss: 0.0948 - mean_iou: 0.7569 - val_loss: 0.0889 - val_mean_iou: 0.7607
#
# Epoch 00009: val_loss did not improve from 0.08892
# Epoch 10/30
# 603/603 [==============================] - 35s 59ms/step - loss: 0.0942 - mean_iou: 0.7644 - val_loss: 0.0835 - val_mean_iou: 0.7673
#
# Epoch 00010: val_loss improved from 0.08892 to 0.08345, saving model to model-dsbowl2018-1Adam.h5
# Epoch 11/30
# 603/603 [==============================] - 36s 60ms/step - loss: 0.0900 - mean_iou: 0.7705 - val_loss: 0.0814 - val_mean_iou: 0.7736
#
# Epoch 00011: val_loss improved from 0.08345 to 0.08136, saving model to model-dsbowl2018-1Adam.h5
# Epoch 12/30
# 603/603 [==============================] - 36s 59ms/step - loss: 0.0869 - mean_iou: 0.7765 - val_loss: 0.0854 - val_mean_iou: 0.7791
#
# Epoch 00012: val_loss did not improve from 0.08136
# Epoch 13/30
# 603/603 [==============================] - 1331s 2s/step - loss: 0.0995 - mean_iou: 0.7809 - val_loss: 0.0991 - val_mean_iou: 0.7825
#
# Epoch 00013: val_loss did not improve from 0.08136
# Epoch 14/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.0875 - mean_iou: 0.7840 - val_loss: 0.0760 - val_mean_iou: 0.7862
#
# Epoch 00014: val_loss improved from 0.08136 to 0.07599, saving model to model-dsbowl2018-1Adam.h5
# Epoch 15/30
# 603/603 [==============================] - 37s 61ms/step - loss: 0.0817 - mean_iou: 0.7883 - val_loss: 0.0740 - val_mean_iou: 0.7902
#
# Epoch 00015: val_loss improved from 0.07599 to 0.07402, saving model to model-dsbowl2018-1Adam.h5
# Epoch 16/30
# 603/603 [==============================] - 36s 59ms/step - loss: 0.0787 - mean_iou: 0.7920 - val_loss: 0.0752 - val_mean_iou: 0.7940
#
# Epoch 00016: val_loss did not improve from 0.07402
# Epoch 17/30
# 603/603 [==============================] - 38s 64ms/step - loss: 0.0770 - mean_iou: 0.7959 - val_loss: 0.0815 - val_mean_iou: 0.7975
#
# Epoch 00017: val_loss did not improve from 0.07402
# Epoch 18/30
# 603/603 [==============================] - 36s 59ms/step - loss: 0.0789 - mean_iou: 0.7988 - val_loss: 0.0779 - val_mean_iou: 0.8003
#
# Epoch 00018: val_loss did not improve from 0.07402
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 47s 77ms/step - loss: 0.0835 - mean_iou: 0.8324 - val_loss: 0.0723 - val_mean_iou: 0.8489
#
# Epoch 00001: val_loss improved from inf to 0.07232, saving model to model-dsbowl2018-1RMSprop.h5
# Epoch 2/30
# 603/603 [==============================] - 39s 64ms/step - loss: 0.0802 - mean_iou: 0.8524 - val_loss: 0.0725 - val_mean_iou: 0.8500
#
# Epoch 00002: val_loss did not improve from 0.07232
# Epoch 3/30
# 603/603 [==============================] - 39s 64ms/step - loss: 0.0794 - mean_iou: 0.8496 - val_loss: 0.0720 - val_mean_iou: 0.8497
#
# Epoch 00003: val_loss improved from 0.07232 to 0.07199, saving model to model-dsbowl2018-1RMSprop.h5
# Epoch 4/30
# 603/603 [==============================] - 41s 69ms/step - loss: 0.0776 - mean_iou: 0.8504 - val_loss: 0.0862 - val_mean_iou: 0.8506
#
# Epoch 00004: val_loss did not improve from 0.07199
# Epoch 5/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.0761 - mean_iou: 0.8497 - val_loss: 0.0689 - val_mean_iou: 0.8506
#
# Epoch 00005: val_loss improved from 0.07199 to 0.06892, saving model to model-dsbowl2018-1RMSprop.h5
# Epoch 6/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.0758 - mean_iou: 0.8512 - val_loss: 0.1113 - val_mean_iou: 0.8516
#
# Epoch 00006: val_loss did not improve from 0.06892
# Epoch 7/30
# 603/603 [==============================] - 37s 62ms/step - loss: 0.0754 - mean_iou: 0.8525 - val_loss: 0.0692 - val_mean_iou: 0.8528
#
# Epoch 00007: val_loss did not improve from 0.06892
# Epoch 8/30
# 603/603 [==============================] - 37s 61ms/step - loss: 0.0736 - mean_iou: 0.8535 - val_loss: 0.1029 - val_mean_iou: 0.8536
#
# Epoch 00008: val_loss did not improve from 0.06892
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 45s 74ms/step - loss: 0.2309 - mean_iou: 0.6928 - val_loss: 0.0716 - val_mean_iou: 0.7930
#
# Epoch 00001: val_loss improved from inf to 0.07159, saving model to model-dsbowl2018-1Adagrad.h5
# Epoch 2/30
# 603/603 [==============================] - 3884s 6s/step - loss: 0.0743 - mean_iou: 0.8108 - val_loss: 0.0708 - val_mean_iou: 0.8242
#
# Epoch 00002: val_loss improved from 0.07159 to 0.07082, saving model to model-dsbowl2018-1Adagrad.h5
# Epoch 3/30
# 603/603 [==============================] - 40s 67ms/step - loss: 0.0715 - mean_iou: 0.8315 - val_loss: 0.0758 - val_mean_iou: 0.8369
#
# Epoch 00003: val_loss did not improve from 0.07082
# Epoch 4/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.0707 - mean_iou: 0.8412 - val_loss: 0.0709 - val_mean_iou: 0.8438
#
# Epoch 00004: val_loss did not improve from 0.07082
# Epoch 5/30
# 603/603 [==============================] - 38s 64ms/step - loss: 0.0692 - mean_iou: 0.8464 - val_loss: 0.0677 - val_mean_iou: 0.8483
#
# Epoch 00005: val_loss improved from 0.07082 to 0.06771, saving model to model-dsbowl2018-1Adagrad.h5
# Epoch 6/30
# 603/603 [==============================] - 39s 64ms/step - loss: 0.0684 - mean_iou: 0.8499 - val_loss: 0.0674 - val_mean_iou: 0.8512
#
# Epoch 00006: val_loss improved from 0.06771 to 0.06736, saving model to model-dsbowl2018-1Adagrad.h5
# Epoch 7/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.0675 - mean_iou: 0.8525 - val_loss: 0.0671 - val_mean_iou: 0.8537
#
# Epoch 00007: val_loss improved from 0.06736 to 0.06708, saving model to model-dsbowl2018-1Adagrad.h5
# Epoch 8/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.0669 - mean_iou: 0.8547 - val_loss: 0.0667 - val_mean_iou: 0.8556
#
# Epoch 00008: val_loss improved from 0.06708 to 0.06669, saving model to model-dsbowl2018-1Adagrad.h5
# Epoch 9/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.0665 - mean_iou: 0.8567 - val_loss: 0.0653 - val_mean_iou: 0.8573
#
# Epoch 00009: val_loss improved from 0.06669 to 0.06528, saving model to model-dsbowl2018-1Adagrad.h5
# Epoch 10/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.0656 - mean_iou: 0.8577 - val_loss: 0.0691 - val_mean_iou: 0.8585
#
# Epoch 00010: val_loss did not improve from 0.06528
# Epoch 11/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.0652 - mean_iou: 0.8592 - val_loss: 0.0671 - val_mean_iou: 0.8598
#
# Epoch 00011: val_loss did not improve from 0.06528
# Epoch 12/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.0642 - mean_iou: 0.8603 - val_loss: 0.0725 - val_mean_iou: 0.8608
#
# Epoch 00012: val_loss did not improve from 0.06528
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 46s 76ms/step - loss: 0.0672 - mean_iou: 0.8588 - val_loss: 0.0719 - val_mean_iou: 0.8701
#
# Epoch 00001: val_loss improved from inf to 0.07186, saving model to model-dsbowl2018-1Adadelta.h5
# Epoch 2/30
# 603/603 [==============================] - 37s 62ms/step - loss: 0.0667 - mean_iou: 0.8701 - val_loss: 0.0730 - val_mean_iou: 0.8698
#
# Epoch 00002: val_loss did not improve from 0.07186
# Epoch 3/30
# 603/603 [==============================] - 37s 61ms/step - loss: 0.0668 - mean_iou: 0.8692 - val_loss: 0.0671 - val_mean_iou: 0.8693
# Epoch 00003: val_loss improved from 0.07186 to 0.06714, saving model to model-dsbowl2018-1Adadelta.h5
# Epoch 4/30
# 603/603 [==============================] - 36s 59ms/step - loss: 0.0654 - mean_iou: 0.8696 - val_loss: 0.0697 - val_mean_iou: 0.8698
#
# Epoch 00004: val_loss did not improve from 0.06714
# Epoch 5/30
# 603/603 [==============================] - 37s 61ms/step - loss: 0.0660 - mean_iou: 0.8703 - val_loss: 0.0718 - val_mean_iou: 0.8699
#
# Epoch 00005: val_loss did not improve from 0.06714
# Epoch 6/30
# 603/603 [==============================] - 40s 67ms/step - loss: 0.0644 - mean_iou: 0.8703 - val_loss: 0.0653 - val_mean_iou: 0.8707
#
# Epoch 00006: val_loss improved from 0.06714 to 0.06527, saving model to model-dsbowl2018-1Adadelta.h5
# Epoch 7/30
# 603/603 [==============================] - 40s 66ms/step - loss: 0.0655 - mean_iou: 0.8703 - val_loss: 0.0662 - val_mean_iou: 0.8708
#
# Epoch 00007: val_loss did not improve from 0.06527
# Epoch 8/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.0641 - mean_iou: 0.8712 - val_loss: 0.0678 - val_mean_iou: 0.8713
#
# Epoch 00008: val_loss did not improve from 0.06527
# Epoch 9/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.0636 - mean_iou: 0.8717 - val_loss: 0.0659 - val_mean_iou: 0.8717
#
# Epoch 00009: val_loss did not improve from 0.06527
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 44s 73ms/step - loss: 0.0739 - mean_iou: 0.8593 - val_loss: 0.0692 - val_mean_iou: 0.8626
#
# Epoch 00001: val_loss improved from inf to 0.06923, saving model to model-dsbowl2018-1Nadam.h5
# Epoch 2/30
# 603/603 [==============================] - 38s 63ms/step - loss: 0.0697 - mean_iou: 0.8633 - val_loss: 0.0810 - val_mean_iou: 0.8633
#
# Epoch 00002: val_loss did not improve from 0.06923
# Epoch 3/30
# 603/603 [==============================] - 39s 65ms/step - loss: 0.1655 - mean_iou: 0.8449 - val_loss: 0.0796 - val_mean_iou: 0.8306
#
# Epoch 00003: val_loss did not improve from 0.06923
# Epoch 4/30
# 603/603 [==============================] - 37s 62ms/step - loss: 0.0931 - mean_iou: 0.8321 - val_loss: 0.0800 - val_mean_iou: 0.8320
#
# Epoch 00004: val_loss did not improve from 0.06923

# %% [markdown]
# 以上の学習から各optimizerのlossと評価関数の値は下記の通り。
#
# - SGD : val_loss  0.21166  val_mean_iou: 0.4693
# - Adam : val_loss  0.07101 val_mean_iou: 0.8139
# - Adagrad : val_loss 0.06724 val_mean_iou: 0.8648
# - Adadelta : val_loss 0.06985 val_mean_iou: 0.8804
# - Nadam : val_loss 0.06679  val_mean_iou: 0.8867
#
#  Nadamが一番精度がよかった。
